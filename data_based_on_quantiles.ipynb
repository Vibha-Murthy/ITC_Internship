# %% [markdown]
# <a href="https://colab.research.google.com/github/Vibha-Murthy/ITC_Internship/blob/main/data_based_on_quantiles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics

# %%
x_axis = np.arange(6, 8, 0.01)
plt.plot(x_axis, norm.pdf(x_axis, 6.7854e+00, 8.3155e-02))
plt.show()

# %%
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt

mu = 6.7854e+00
sigma = 8.3155e-02

# define the normal distribution and PDF
dist = sps.norm(loc=mu, scale=sigma)
x = np.linspace(dist.ppf(.001), dist.ppf(.999))
y = dist.pdf(x)

# calculate PPFs
ppfs = {}
for ppf in [.01, .05, .25, .5, .75,.95, .99]:
    p = dist.ppf(ppf)
    ppfs.update({ppf*100: p})

# plot results
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(x, y, color='k')
for i, ppf in enumerate(ppfs):
    ax.axvline(ppfs[ppf], color=f'C{i}', label=f'{ppf:.0f}th: {ppfs[ppf]:.1f}')
ax.legend()
plt.show()
